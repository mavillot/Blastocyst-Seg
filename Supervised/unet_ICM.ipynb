# %%
import tensorflow as tf
import numpy as np
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate
from keras.losses import BinaryCrossentropy
from keras.metrics import MeanIoU
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from pathlib import Path
import os
import cv2
import imutils
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Dataset

# %%
path=Path('../../../0_data/Processed/Saeedi/')
path_train=path/'train_def'
path_test=path/'test_def'
path_gt=path/'GT_ICM'
path_models=Path('../../../3_models/')

# %% [markdown]
# ### Load dataset

# %%
dim=(256,256)
def load_imgs(path, path_gt=''):
    files=[path/f for f in os.listdir(path)]
    x = np.array([cv2.resize(cv2.imread(str(f),cv2.IMREAD_GRAYSCALE), dim) for f in files])
    if path_gt == '':
        y=None
    else:
        y = np.array([cv2.threshold(cv2.resize(cv2.imread(str(path_gt/(f.stem+' ICM_Mask.bmp')),cv2.IMREAD_GRAYSCALE), dim),127,255,cv2.THRESH_BINARY)[1] for f in files])
    return x,y

# %%
x_train, y_train = load_imgs(path_train, path_gt)
x_test, y_test = load_imgs(path_test, path_gt)

# %% [markdown]
# ### Standard normalization

# %%
def std_norm(x):
    mean, std= np.mean(x, axis=0), np.std(x, axis=0) 
    return ((x.astype('float32') - mean) / std , mean, std)

def std_norm_test(x,mean,std):
    return (x.astype('float32') - mean) / std

# %%
x_train, mean, std = std_norm(x_train)
x_test = std_norm_test(x_test, mean, std)

# %% [markdown]
# ### Data augmentation

# %%
def data_augmentation(x_train, y_train):
    x_train_augmented, y_train_augmented=[], []
    for k in range(len(x_train)):
        img=x_train[k]
        mask=y_train[k]
        for i in range(37):
            x_train_augmented.append(imutils.rotate(img, angle=10*i))
            y_train_augmented.append(imutils.rotate(mask, angle=10*i))
    return np.array(x_train_augmented), np.array(y_train_augmented)

# %%
x_train, y_train = data_augmentation(x_train, y_train)

# %%
x_train = x_train.astype("float32") 
y_train = y_train.astype("float32")/255  

x_test = x_test.astype("float32") 
y_test = y_test.astype("float32")/255

# %% [markdown]
# ### Randomize data

# %%
x_train, y_train = shuffle(x_train, y_train, random_state=13)

# %% [markdown]
# # Model

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same", activation='relu')(input)
    x = Dropout(0.05) (x)
    x = Conv2D(num_filters, 3, padding="same", activation='relu')(x)
    x = Dropout(0.05) (x)
    return x

#Encoder block: Conv block followed by maxpooling and residual block

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters) # convolutional block
    x = BatchNormalization()(x)
    input = Conv2D(num_filters, 1, padding="same")(input)
    transfer = tf.math.add(x,input)
    p = MaxPool2D(2)(transfer) #subsampling block  
    p = Activation("relu")(p)
    return x, p  


#Bottleneck block: 4 dilaten convolution layers

def bottleneck_block(input, num_filters):
    x1 = Conv2D(num_filters, 3, dilation_rate=1,  padding="same" )(input)
    x1 =  Dropout(0.05) (x1)
    x2 = Conv2D(num_filters, 3, dilation_rate=2, padding="same" )(x1)
    x2 =  Dropout(0.05) (x2)
    x3 = Conv2D(num_filters, 3, dilation_rate=4, padding="same" )(x2)
    x3 =  Dropout(0.05) (x3)
    x4 = Conv2D(num_filters, 3, dilation_rate=8, padding="same" )(x3)
    x4 =  Dropout(0.05) (x4)
    c = Concatenate(axis=3)([x1, x2, x3, x4])
    x = Conv2D(num_filters, 3, padding="same", activation='relu')(c)
    x = Dropout(0.05) (x)
    return  x


#Decoder block
#skip features gets input from encoder for concatenation

def decoder_block(input, skip_features, num_filters):
    x = UpSampling2D(size=2)(input)
    x = BatchNormalization()(x) 
    x1 = Concatenate(axis=3)([x, skip_features])
      
    x = Conv2D(num_filters, 3, padding="same", activation='relu')(x1)
    x = Dropout(0.05) (x)
    x = Conv2D(num_filters, 3, padding="same", activation='relu')(x)
    x = Dropout(0.05) (x)
    x1 = Conv2D(num_filters, 1, padding="same")(x1)
    return tf.math.add(x,x1)

#Build Unet using the blocks
def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 16)
    s2, p2 = encoder_block(p1, 32)
    s3, p3 = encoder_block(p2, 64)
    s4, p4 = encoder_block(p3, 128)

    b1   = bottleneck_block(p4, 128) #Bridge

    d1 = decoder_block(b1, s4, 128)
    d2 = decoder_block(d1, s3, 64)
    d3 = decoder_block(d2, s2, 32)
    d4 = decoder_block(d3, s1, 16)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)  
    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
model= build_unet(input_shape=(256,256,1))

# %% [markdown]
# ### Loss function

# %%
def jaccard_index(y_true, y_pred):
    """ Calculates mean of Jaccard index as a loss function """
    intersection = tf.reduce_sum(y_true * y_pred, axis=(1,2))
    sum_ = tf.reduce_sum(y_true + y_pred, axis=(1,2))
    jac = (intersection) / (sum_ - intersection)
    return tf.reduce_mean(jac)

def my_loss_fn(y_true, y_pred):
    return BinaryCrossentropy(from_logits=True)(y_true, y_pred)-tf.math.log(jaccard_index(y_true, y_pred))

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    # Loss function to minimize
    loss=my_loss_fn,
    # List of metrics to monitor
    metrics=[jaccard_index])

# %%
callbacks = [
    EarlyStopping(patience=15),
    ModelCheckpoint(filepath=path_models+'models/model.{epoch:02d}-{val_loss:.2f}.h5'),
    ReduceLROnPlateau(factor=0.05, patience=5)]

# %%
from tensorflow.keras.utils import Sequence
class DataGenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_x, batch_y=shuffle(batch_x, batch_y, random_state=1)
        return batch_x, batch_y

# %% [markdown]
# ### Training

# %%
history = model.fit(
    DataGenerator(x_train, y_train, 16),
    batch_size=16,
    epochs=200,
    callbacks=callbacks,
    validation_data=(x_test, y_test))
# Out:
# Epoch 1/200
# 488/488 [==============================] - 100s 179ms/step - loss: 1.3057 - jaccard_index: 0.5972 - val_loss: 1.1834 - val_jaccard_index: 0.5959
# Epoch 2/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.9484 - jaccard_index: 0.7607 - val_loss: 0.9854 - val_jaccard_index: 0.7374
# Epoch 3/200
# 488/488 [==============================] - 86s 176ms/step - loss: 0.9046 - jaccard_index: 0.7934 - val_loss: 0.9863 - val_jaccard_index: 0.7412
# Epoch 4/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.8769 - jaccard_index: 0.8146 - val_loss: 1.0328 - val_jaccard_index: 0.7170
# Epoch 5/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.8568 - jaccard_index: 0.8305 - val_loss: 0.9939 - val_jaccard_index: 0.7422
# Epoch 6/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.8409 - jaccard_index: 0.8432 - val_loss: 0.9488 - val_jaccard_index: 0.7631
# Epoch 7/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.8292 - jaccard_index: 0.8527 - val_loss: 0.9375 - val_jaccard_index: 0.7739
# Epoch 8/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.8181 - jaccard_index: 0.8619 - val_loss: 0.9505 - val_jaccard_index: 0.7583
# Epoch 9/200
# 488/488 [==============================] - 82s 169ms/step - loss: 0.8106 - jaccard_index: 0.8681 - val_loss: 0.9401 - val_jaccard_index: 0.7709
# Epoch 10/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.8016 - jaccard_index: 0.8757 - val_loss: 0.9385 - val_jaccard_index: 0.7792
# Epoch 11/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7959 - jaccard_index: 0.8805 - val_loss: 0.9293 - val_jaccard_index: 0.7777
# Epoch 12/200
# 488/488 [==============================] - 86s 175ms/step - loss: 0.7880 - jaccard_index: 0.8872 - val_loss: 0.9109 - val_jaccard_index: 0.7976
# Epoch 13/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7827 - jaccard_index: 0.8917 - val_loss: 0.9135 - val_jaccard_index: 0.7842
# Epoch 14/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7776 - jaccard_index: 0.8961 - val_loss: 0.9227 - val_jaccard_index: 0.7852
# Epoch 15/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7760 - jaccard_index: 0.8974 - val_loss: 0.9115 - val_jaccard_index: 0.7948
# Epoch 16/200
# 488/488 [==============================] - 82s 169ms/step - loss: 0.7692 - jaccard_index: 0.9033 - val_loss: 0.9199 - val_jaccard_index: 0.7774
# Epoch 17/200
# 488/488 [==============================] - 83s 169ms/step - loss: 0.7665 - jaccard_index: 0.9057 - val_loss: 0.9219 - val_jaccard_index: 0.7771
# Epoch 18/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7585 - jaccard_index: 0.9127 - val_loss: 0.9150 - val_jaccard_index: 0.7872
# Epoch 19/200
# 488/488 [==============================] - 83s 169ms/step - loss: 0.7550 - jaccard_index: 0.9157 - val_loss: 0.9123 - val_jaccard_index: 0.7918
# Epoch 20/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7536 - jaccard_index: 0.9169 - val_loss: 0.9117 - val_jaccard_index: 0.7931
# Epoch 21/200
# 488/488 [==============================] - 86s 176ms/step - loss: 0.7523 - jaccard_index: 0.9180 - val_loss: 0.9114 - val_jaccard_index: 0.7933
# Epoch 22/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7518 - jaccard_index: 0.9186 - val_loss: 0.9122 - val_jaccard_index: 0.7945
# Epoch 23/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7507 - jaccard_index: 0.9195 - val_loss: 0.9106 - val_jaccard_index: 0.7948
# Epoch 24/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7509 - jaccard_index: 0.9193 - val_loss: 0.9091 - val_jaccard_index: 0.7960
# Epoch 25/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7507 - jaccard_index: 0.9195 - val_loss: 0.9099 - val_jaccard_index: 0.7954
# Epoch 26/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7507 - jaccard_index: 0.9195 - val_loss: 0.9098 - val_jaccard_index: 0.7953
# Epoch 27/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7508 - jaccard_index: 0.9194 - val_loss: 0.9089 - val_jaccard_index: 0.7959
# Epoch 28/200
# 488/488 [==============================] - 81s 167ms/step - loss: 0.7504 - jaccard_index: 0.9198 - val_loss: 0.9089 - val_jaccard_index: 0.7957
# Epoch 29/200
# 488/488 [==============================] - 81s 166ms/step - loss: 0.7506 - jaccard_index: 0.9196 - val_loss: 0.9083 - val_jaccard_index: 0.7962
# Epoch 30/200
# 488/488 [==============================] - 86s 175ms/step - loss: 0.7504 - jaccard_index: 0.9197 - val_loss: 0.9088 - val_jaccard_index: 0.7960
# Epoch 31/200
# 488/488 [==============================] - 81s 166ms/step - loss: 0.7506 - jaccard_index: 0.9196 - val_loss: 0.9096 - val_jaccard_index: 0.7953
# Epoch 32/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7504 - jaccard_index: 0.9198 - val_loss: 0.9094 - val_jaccard_index: 0.7958
# Epoch 33/200
# 488/488 [==============================] - 81s 166ms/step - loss: 0.7503 - jaccard_index: 0.9198 - val_loss: 0.9081 - val_jaccard_index: 0.7965
# Epoch 34/200
# 488/488 [==============================] - 81s 167ms/step - loss: 0.7506 - jaccard_index: 0.9196 - val_loss: 0.9088 - val_jaccard_index: 0.7959
# Epoch 35/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7504 - jaccard_index: 0.9198 - val_loss: 0.9089 - val_jaccard_index: 0.7960
# Epoch 36/200
# 488/488 [==============================] - 81s 167ms/step - loss: 0.7504 - jaccard_index: 0.9198 - val_loss: 0.9097 - val_jaccard_index: 0.7954
# Epoch 37/200
# 488/488 [==============================] - 81s 167ms/step - loss: 0.7501 - jaccard_index: 0.9201 - val_loss: 0.9087 - val_jaccard_index: 0.7960
# Epoch 38/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7502 - jaccard_index: 0.9199 - val_loss: 0.9094 - val_jaccard_index: 0.7956
# Epoch 39/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7502 - jaccard_index: 0.9199 - val_loss: 0.9097 - val_jaccard_index: 0.7954
# Epoch 40/200
# 488/488 [==============================] - 86s 176ms/step - loss: 0.7503 - jaccard_index: 0.9199 - val_loss: 0.9086 - val_jaccard_index: 0.7961
# Epoch 41/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7501 - jaccard_index: 0.9200 - val_loss: 0.9080 - val_jaccard_index: 0.7965
# Epoch 42/200
# 488/488 [==============================] - 82s 169ms/step - loss: 0.7504 - jaccard_index: 0.9198 - val_loss: 0.9084 - val_jaccard_index: 0.7963
# Epoch 43/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7502 - jaccard_index: 0.9199 - val_loss: 0.9088 - val_jaccard_index: 0.7961
# Epoch 44/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7501 - jaccard_index: 0.9200 - val_loss: 0.9087 - val_jaccard_index: 0.7963
# Epoch 45/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7502 - jaccard_index: 0.9199 - val_loss: 0.9091 - val_jaccard_index: 0.7958
# Epoch 46/200
# 488/488 [==============================] - 81s 167ms/step - loss: 0.7501 - jaccard_index: 0.9201 - val_loss: 0.9085 - val_jaccard_index: 0.7963
# Epoch 47/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7502 - jaccard_index: 0.9199 - val_loss: 0.9091 - val_jaccard_index: 0.7959
# Epoch 48/200
# 488/488 [==============================] - 81s 166ms/step - loss: 0.7503 - jaccard_index: 0.9199 - val_loss: 0.9089 - val_jaccard_index: 0.7959
# Epoch 49/200
# 488/488 [==============================] - 86s 176ms/step - loss: 0.7500 - jaccard_index: 0.9201 - val_loss: 0.9085 - val_jaccard_index: 0.7962
# Epoch 50/200
# 488/488 [==============================] - 81s 167ms/step - loss: 0.7501 - jaccard_index: 0.9200 - val_loss: 0.9089 - val_jaccard_index: 0.7961
# Epoch 51/200
# 488/488 [==============================] - 81s 166ms/step - loss: 0.7502 - jaccard_index: 0.9199 - val_loss: 0.9087 - val_jaccard_index: 0.7961
# Epoch 52/200
# 488/488 [==============================] - 82s 167ms/step - loss: 0.7502 - jaccard_index: 0.9200 - val_loss: 0.9084 - val_jaccard_index: 0.7963
# Epoch 53/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7501 - jaccard_index: 0.9200 - val_loss: 0.9085 - val_jaccard_index: 0.7963
# Epoch 54/200
# 488/488 [==============================] - 81s 166ms/step - loss: 0.7501 - jaccard_index: 0.9201 - val_loss: 0.9092 - val_jaccard_index: 0.7957
# Epoch 55/200
# 488/488 [==============================] - 82s 168ms/step - loss: 0.7504 - jaccard_index: 0.9198 - val_loss: 0.9083 - val_jaccard_index: 0.7966
# Epoch 56/200
# 488/488 [==============================] - 82s 169ms/step - loss: 0.7503 - jaccard_index: 0.9199 - val_loss: 0.9086 - val_jaccard_index: 0.7962

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
model.save('unet_ICM')
# Out:
# INFO:tensorflow:Assets written to: unet_ICM\assets

# %% [markdown]
# # Evaluación

# %%
model = tf.keras.models.load_model(path_models/'unet_ICM', custom_objects={'jaccard_index':jaccard_index, 'my_loss_fn':my_loss_fn})

# %%
results = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 1/1 [==============================] - 14s 14s/step - loss: 0.9094 - jaccard_index: 0.7898

# %%
predictions = model.predict(x_test)

# %% [markdown]
# ## Metrics

# %%
def accuracy(target, prediction):
    true_detec = np.logical_not(np.logical_xor(target, prediction))
    return np.sum(true_detec)/np.sum(np.ones_like(target))

def precision(target, prediction):
    intersection = np.logical_and(target, prediction)
    return np.sum(intersection)/np.sum(prediction)

def recall(target, prediction):
    intersection = np.logical_and(target, prediction)
    return np.sum(intersection)/np.sum(target)

def jaccard(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    return np.sum(intersection) / np.sum(union)

def dice(target, prediction):
    intersection = np.logical_and(target, prediction)
    return 2*np.sum(intersection) / (np.sum(target) + np.sum(prediction))

# %%
def metrics(target, prediction):
    return {'accuracy': accuracy(target, prediction),
            'precision': precision(target, prediction),
            'recall': recall(target, prediction),
            'specificity': recall(1-target,1- prediction),
            'jaccard':jaccard(target, prediction),
            'dice': dice(target, prediction)}

# %%
def summary_metrics(y_test,predictions,thresh=0.5):
    a,p,r,s,j,d=0.,0.,0.,0.,0.,0.
    n=len(predictions)
    for i in range(n):
        preds= (predictions[i][:,:,0]>=thresh).astype('uint8')
        gt= y_test[i].astype('uint8')
        metricas=metrics(gt,preds)
        a+=metricas['accuracy']
        p+=metricas['precision']
        r+=metricas['recall']
        s+=metricas['specificity']
        j+=metricas['jaccard']
        d+=metricas['dice']
    return {'accuracy': a/n,
            'precision': p/n,
            'recall': r/n,
            'specificity': s/n,
            'jaccard':j/n,
            'dice': d/n}

# %%
summary_metrics(y_test,predictions, 0.5)
# Out:
# {'accuracy': 0.979876066509046,
#  'precision': 0.8843877898756088,
#  'recall': 0.8845026371967324,
#  'specificity': 0.989439413876417,
#  'jaccard': 0.7899381395424538,
#  'dice': 0.8744947609191968}

# %% [markdown]
# # Imágenes de Clara Malo

# %%
path=Path('../../../0_data/Processed/Clara/embriones')
img_clara, _ = load_imgs(path)
img_clara,_,_ = std_norm(img_clara)

# %%
predictions = model.predict(img_clara)

# %%
path_out=Path('../../../4_output/')
#os.mkdir(path_out/'Clara'/'ICM'/'UNet')

# %%
files=[path/f for f in os.listdir(path)]

# %%
dims=[cv2.imread(str(f), cv2.IMREAD_GRAYSCALE).shape[::-1] for f in [path/f for f in os.listdir(path)]]

# %%
i=0
for p in predictions:
    img=255*(p[:,:,0]>0.5).astype('uint8')
    cv2.imwrite(str(path_out/'Clara'/'ICM'/'UNet'/files[i].name), cv2.resize(img, dims[i]))
    i+=1
